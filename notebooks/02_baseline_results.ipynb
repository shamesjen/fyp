# %% [markdown]
# # Baseline Results
#
# Load the baseline summary CSV after running `scripts/run_baselines.py`.

# %%
from pathlib import Path

import pandas as pd

root = Path.cwd().resolve()
summary_path = root / 'artifacts' / 'baselines' / 'baseline_summary.csv'
pd.read_csv(summary_path) if summary_path.exists() else 'Run scripts/run_baselines.py first'
