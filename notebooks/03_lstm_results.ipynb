# %% [markdown]
# # LSTM Results
#
# Inspect the saved LSTM metrics and prediction frame.

# %%
import json
from pathlib import Path

import pandas as pd

root = Path.cwd().resolve()
metrics_path = root / 'artifacts' / 'lstm' / 'lstm_metrics.json'
pred_path = root / 'artifacts' / 'lstm' / 'test_predictions.csv'
(
    json.loads(metrics_path.read_text()) if metrics_path.exists() else 'Run scripts/run_lstm.py first',
    pd.read_csv(pred_path).head() if pred_path.exists() else 'No predictions yet'
)
